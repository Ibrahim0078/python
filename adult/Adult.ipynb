# %%
import numpy as np
import pandas as pd

df = pd.read_csv("C:\\Users\\ibrah\\Python\\adult\\adult.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df.nunique()
# Out:
# age                   74
# workclass              9
# fnlwgt             28523
# education             16
# educational-num       16
# marital-status         7
# occupation            15
# relationship           6
# race                   5
# gender                 2
# capital-gain         123
# capital-loss          99
# hours-per-week        96
# native-country        42
# income                 2
# dtype: int64

# %%
df['income'].value_counts(normalize = True) * 100
# Out:
# income
# <=50K    76.071823
# >50K     23.928177
# Name: proportion, dtype: float64

# %%
df['income'].value_counts()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df['age'].value_counts().sort_index()
# Out:
# age
# 17     595
# 18     862
# 19    1053
# 20    1113
# 21    1096
#       ...
# 86       1
# 87       3
# 88       6
# 89       2
# 90      55
# Name: count, Length: 74, dtype: int64

# %%
df["hours-per-week"].value_counts().sort_index()
# Out:
# hours-per-week
# 1      27
# 2      53
# 3      59
# 4      84
# 5      95
#      ...
# 95      2
# 96      9
# 97      2
# 98     14
# 99    137
# Name: count, Length: 96, dtype: int64

# %%
df['hours-per-week'].describe()
# Out:
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
df['hours-per-week'].min()   # lowest values
# Out:
# 1

# %%
df['hours-per-week'].max()   # highest values
# Out:
# 99

# %%
df[['age', 'workclass', 'education', 'capital-gain']].sort_values('capital-gain', ascending=False).head(5)
# Out:
#        age         workclass  education  capital-gain
# 16030   36           Private  Bachelors         99999
# 14450   40      Self-emp-inc  Doctorate         99999
# 14624   48  Self-emp-not-inc  Doctorate         99999
# 23853   63           Private    HS-grad         99999
# 31108   33           Private  Bachelors         99999

# %%
df[['age', 'workclass', 'education', 'capital-loss']].sort_values('capital-loss', ascending=False).head(5)
# Out:
#        age workclass     education  capital-loss
# 25244   90         ?       HS-grad          4356
# 31037   82   Private       HS-grad          4356
# 47062   66         ?  Some-college          4356
# 40083   41   Private  Some-college          3900
# 36697   54   Private       7th-8th          3900

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df[['education', 'educational-num']].drop_duplicates().sort_values('educational-num')
# Out:
#         education  educational-num
# 779     Preschool                1
# 323       1st-4th                2
# 37        5th-6th                3
# 9         7th-8th                4
# 54            9th                5
# 5            10th                6
# 0            11th                7
# 173          12th                8
# 1         HS-grad                9
# 3    Some-college               10
# 41      Assoc-voc               11
# 2      Assoc-acdm               12
# 11      Bachelors               13
# 15        Masters               14
# 7     Prof-school               15
# 19      Doctorate               16

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=True) * 100
# Out:
# gender
# Male      66.848204
# Female    33.151796
# Name: proportion, dtype: float64

# %%
df['race'].value_counts()
# Out:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %%
pd.crosstab(df['education'], df['income'])
# Out:
# income        <=50K  >50K
# education
# 10th           1302    87
# 11th           1720    92
# 12th            609    48
# 1st-4th         239     8
# 5th-6th         482    27
# 7th-8th         893    62
# 9th             715    41
# Assoc-acdm     1188   413
# Assoc-voc      1539   522
# Bachelors      4712  3313
# Doctorate       163   431
# HS-grad       13281  2503
# Masters        1198  1459
# Preschool        82     1
# Prof-school     217   617
# Some-college   8815  2063

# %%
df.groupby('income')['age'].sum()
# Out:
# income
# <=50K    1369986
# >50K      517444
# Name: age, dtype: int64

# %%
df.groupby('income')['age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# income
# <=50K   37155.0  36.872184  14.104118  17.0  25.0  34.0  46.0  90.0
# >50K    11687.0  44.275178  10.558983  19.0  36.0  43.0  51.0  90.0

# %%
pd.crosstab(pd.cut(df['age'], bins=[15,25,35,45,55,65,90]), df['income'])
# Out:
# income    <=50K  >50K
# age
# (15, 25]   9458   169
# (25, 35]  10340  2379
# (35, 45]   7821  4131
# (45, 55]   5041  3255
# (55, 65]   3049  1396
# (65, 90]   1446   357

# %%
pd.crosstab(df['occupation'], df['income'], normalize='index') * 100
# Out:
# income                 <=50K       >50K
# occupation
# ?                  90.566038   9.433962
# Adm-clerical       86.312600  13.687400
# Armed-Forces       66.666667  33.333333
# Craft-repair       77.372382  22.627618
# Exec-managerial    52.218206  47.781794
# Farming-fishing    88.389262  11.610738
# Handlers-cleaners  93.339768   6.660232
# Machine-op-inspct  87.690271  12.309729
# Other-service      95.856185   4.143815
# Priv-house-serv    98.760331   1.239669
# Prof-specialty     54.893065  45.106935
# Protective-serv    68.667345  31.332655
# Sales              73.201308  26.798692
# Tech-support       70.954357  29.045643
# Transport-moving   79.575372  20.424628

# %%
pd.crosstab(df['gender'],df['income'], normalize = True) * 100
# Out:
# income      <=50K       >50K
# gender
# Female  29.529913   3.621883
# Male    46.541911  20.306294

# %%
pd.crosstab(df['race'], df['income'], normalize='index') * 100
# Out:
# income                  <=50K       >50K
# race
# Amer-Indian-Eskimo  88.297872  11.702128
# Asian-Pac-Islander  73.074391  26.925609
# Black               87.918890  12.081110
# Other               87.684729  12.315271
# White               74.601312  25.398688

# %%
df.groupby('income')['hours-per-week'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%   max
# income
# <=50K   37155.0  38.840048  12.356849  1.0  35.0  40.0  40.0  99.0
# >50K    11687.0  45.452896  11.091176  1.0  40.0  40.0  50.0  99.0

# %%
df.groupby('income')['capital-gain'].count()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: capital-gain, dtype: int64

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df['income'].value_counts(normalize = True) * 100
# Out:
# income
# <=50K    76.071823
# >50K     23.928177
# Name: proportion, dtype: float64

# %%
df[['age','fnlwgt','capital-gain','capital-loss','hours-per-week']].agg(['min','max','mean','median'])
# Out:
#               age        fnlwgt  capital-gain  capital-loss  hours-per-week
# min     17.000000  1.228500e+04      0.000000      0.000000        1.000000
# max     90.000000  1.490400e+06  99999.000000   4356.000000       99.000000
# mean    38.643585  1.896641e+05   1079.067626     87.502314       40.422382
# median  37.000000  1.781445e+05      0.000000      0.000000       40.000000

# %%
numeric_cols = df.select_dtypes(include='number').columns

outliers_iqr = {}

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outliers_iqr[col] = len(outliers)

print("Outliers detected using IQR:")
print(outliers_iqr)
# Out:
# Outliers detected using IQR:
# {'age': 216, 'fnlwgt': 1453, 'educational-num': 1794, 'capital-gain': 4035, 'capital-loss': 2282, 'hours-per-week': 13496}

# %%
numeric_cols = df.select_dtypes(include='number').columns

outlier_rows_iqr = {}

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outlier_rows_iqr[col] = outliers  # store full rows

# Example: see outliers for capital-gain
outlier_rows_iqr['capital-gain'].head()
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 3    44           Private  160323  Some-college               10
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 10   65           Private  184454       HS-grad                9
# 14   48           Private  279724       HS-grad                9
# 25   45  Self-emp-not-inc  432824       HS-grad                9
#
#         marital-status         occupation relationship   race gender  \
# 3   Married-civ-spouse  Machine-op-inspct      Husband  Black   Male
# 7   Married-civ-spouse     Prof-specialty      Husband  White   Male
# 10  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
# 14  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
# 25  Married-civ-spouse       Craft-repair      Husband  White   Male
#
#     capital-gain  capital-loss  hours-per-week native-country income
# 3           7688             0              40  United-States   >50K
# ...

# %%
categorical_cols = ['workclass','education','marital-status','occupation',
                    'relationship','race','gender','native-country']

for col in categorical_cols:
    print(f"\nTop 5 in {col}:")
    print(df[col].value_counts().head(5))
# Out:
# Top 5 in workclass:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Name: count, dtype: int64
#
# Top 5 in education:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# Name: count, dtype: int64
#
# Top 5 in marital-status:
# marital-status
# Married-civ-spouse    22379
# Never-married         16117
# Divorced               6633
# Separated              1530
# Widowed                1518
# Name: count, dtype: int64
#
# Top 5 in occupation:
# occupation
# Prof-specialty     6172
# Craft-repair       6112
# Exec-managerial    6086
# Adm-clerical       5611
# Sales              5504
# Name: count, dtype: int64
#
# Top 5 in relationship:
# relationship
# Husband          19716
# Not-in-family    12583
# Own-child         7581
# Unmarried         5125
# Wife              2331
# ...

# %%
df.nunique()
# Out:
# age                   74
# workclass              9
# fnlwgt             28523
# education             16
# educational-num       16
# marital-status         7
# occupation            15
# relationship           6
# race                   5
# gender                 2
# capital-gain         123
# capital-loss          99
# hours-per-week        96
# native-country        42
# income                 2
# dtype: int64

# %%
pd.crosstab(df['education'], df['income'], normalize='index') * 100
# Out:
# income            <=50K       >50K
# education
# 10th          93.736501   6.263499
# 11th          94.922737   5.077263
# 12th          92.694064   7.305936
# 1st-4th       96.761134   3.238866
# 5th-6th       94.695481   5.304519
# 7th-8th       93.507853   6.492147
# 9th           94.576720   5.423280
# Assoc-acdm    74.203623  25.796377
# Assoc-voc     74.672489  25.327511
# Bachelors     58.716511  41.283489
# Doctorate     27.441077  72.558923
# HS-grad       84.142169  15.857831
# Masters       45.088446  54.911554
# Preschool     98.795181   1.204819
# Prof-school   26.019185  73.980815
# Some-college  81.035117  18.964883

# %%
df.groupby('income')['age'].mean()
# Out:
# income
# <=50K    36.872184
# >50K     44.275178
# Name: age, dtype: float64

# %%
df.groupby('income')['hours-per-week'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%   max
# income
# <=50K   37155.0  38.840048  12.356849  1.0  35.0  40.0  40.0  99.0
# >50K    11687.0  45.452896  11.091176  1.0  40.0  40.0  50.0  99.0

# %%
pd.crosstab(df['occupation'], df['income'], normalize='index') * 100
# Out:
# income                 <=50K       >50K
# occupation
# ?                  90.566038   9.433962
# Adm-clerical       86.312600  13.687400
# Armed-Forces       66.666667  33.333333
# Craft-repair       77.372382  22.627618
# Exec-managerial    52.218206  47.781794
# Farming-fishing    88.389262  11.610738
# Handlers-cleaners  93.339768   6.660232
# Machine-op-inspct  87.690271  12.309729
# Other-service      95.856185   4.143815
# Priv-house-serv    98.760331   1.239669
# Prof-specialty     54.893065  45.106935
# Protective-serv    68.667345  31.332655
# Sales              73.201308  26.798692
# Tech-support       70.954357  29.045643
# Transport-moving   79.575372  20.424628

# %%
pd.crosstab(df['workclass'], df['gender'], normalize='index') * 100
# Out:
# gender               Female       Male
# workclass
# ?                 45.373348  54.626652
# Federal-gov       31.564246  68.435754
# Local-gov         40.114796  59.885204
# Never-worked      30.000000  70.000000
# Private           34.209284  65.790716
# Self-emp-inc      12.448378  87.551622
# Self-emp-not-inc  16.286898  83.713102
# State-gov         38.515901  61.484099
# Without-pay       33.333333  66.666667

# %%
(df == '?').sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
(df == '?').sum() / len(df) * 100
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
# Keep only rows that do NOT have '?' in any of those 3 columns:
df = df[(df['workclass'] != '?') &
        (df['occupation'] != '?') &
        (df['native-country'] != '?')]

# %%
(df == 'Unknown').sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df['native-country'].unique()
# Out:
# array(['United-States', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
df['native-country'] = df['native-country'].str.replace('-', ' ')

# %%
df['native-country'].unique()
# Out:
# array(['United States', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El Salvador', 'Puerto Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying US(Guam USVI etc)', 'France',
#        'Holand Netherlands'], dtype=object)

# %%
country_map = {
    'Columbia': 'Colombia',
    'Trinadad&Tobago': 'Trinidad & Tobago',
    'Hong': 'Hong Kong',
    'Holand Netherlands': 'Netherlands',
    # 'South': 'South Korea'   # only if you know what it is
}

df['native-country'] = df['native-country'].replace(country_map)

# %%
df['native-country'].unique()
# Out:
# array(['United States', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El Salvador', 'Puerto Rico', 'Vietnam',
#        'South', 'Colombia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong Kong', 'Greece',
#        'Trinidad & Tobago', 'Outlying US(Guam USVI etc)', 'France',
#        'Netherlands'], dtype=object)

# %%
df[['education', 'educational-num']].drop_duplicates().sort_values('educational-num')
# Out:
#         education  educational-num
# 779     Preschool                1
# 323       1st-4th                2
# 37        5th-6th                3
# 9         7th-8th                4
# 54            9th                5
# 5            10th                6
# 0            11th                7
# 173          12th                8
# 1         HS-grad                9
# 3    Some-college               10
# 41      Assoc-voc               11
# 2      Assoc-acdm               12
# 11      Bachelors               13
# 15        Masters               14
# 7     Prof-school               15
# 126     Doctorate               16

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45222.000000  4.522200e+04     45222.000000  45222.000000
# mean      38.547941  1.897347e+05        10.118460   1101.430344
# std       13.217870  1.056392e+05         2.552881   7506.430084
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173882e+05         9.000000      0.000000
# 50%       37.000000  1.783160e+05        10.000000      0.000000
# 75%       47.000000  2.379260e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45222.000000    45222.000000
# mean      88.595418       40.938017
# std      404.956092       12.007508
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
(df['capital-gain'] == 99999).sum()  # how many rows
# Out:
# np.int64(229)

# %%
df['hours-per-week'].value_counts().head(10)
# Out:
# hours-per-week
# 40    21358
# 50     4094
# 45     2602
# 60     2085
# 35     1776
# 20     1602
# 30     1467
# 55     1020
# 25      820
# 48      733
# Name: count, dtype: int64

# %%
import numpy as np
df['capital-gain'] = df['capital-gain'].replace(99999, np.nan)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# educational-num      0
# marital-status       0
# occupation           0
# relationship         0
# race                 0
# gender               0
# capital-gain       229
# capital-loss         0
# hours-per-week       0
# native-country       0
# income               0
# dtype: int64

# %%
(df == '?').sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# Check NaN values
print(df.isna().sum())

# Check empty strings
print((df == '').sum())
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# educational-num      0
# marital-status       0
# occupation           0
# relationship         0
# race                 0
# gender               0
# capital-gain       229
# capital-loss         0
# hours-per-week       0
# native-country       0
# income               0
# dtype: int64
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# Count rows with '?' in workclass
workclass_missing = (df['workclass'] == '?').sum()

# Count rows with '?' in occupation
occupation_missing = (df['occupation'] == '?').sum()

print(workclass_missing, occupation_missing)
# Out:
# 0 0

# %%
# Boolean Series of duplicates (True if the row is duplicate of a previous one)
df.duplicated()

# Count how many duplicates:
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 47

# %%
df[df.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 864     24           Private  194630     Bachelors               13
# 11189   37           Private   52870     Bachelors               13
# 11212   29           Private   36440     Bachelors               13
# 13848   30           Private  180317     Assoc-voc               11
# 15960   18      Self-emp-inc  378036          12th                8
# 18476   39           Private  184659       HS-grad                9
# 19399   19           Private  130431       5th-6th                3
# 19726   41           Private  116391     Bachelors               13
# 20606   25           Private  308144     Bachelors               13
# 21162   25           Private  308144     Bachelors               13
# 21385   90           Private   52386  Some-college               10
# 24361   21           Private  243368     Preschool                1
# 25452   21           Private  250051  Some-college               10
# ...

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"\nUnique values in {col}:")
    print(df[col].unique())
# Out:
# Unique values in workclass:
# ['Private' 'Local-gov' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay']
#
# Unique values in education:
# ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' '5th-6th' 'Assoc-voc' '9th' 'Doctorate'
#  '12th' '1st-4th' 'Preschool']
#
# Unique values in marital-status:
# ['Never-married' 'Married-civ-spouse' 'Widowed' 'Separated' 'Divorced'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
# Unique values in occupation:
# ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' 'Other-service'
#  'Prof-specialty' 'Craft-repair' 'Adm-clerical' 'Exec-managerial'
#  'Tech-support' 'Sales' 'Priv-house-serv' 'Transport-moving'
#  'Handlers-cleaners' 'Armed-Forces']
#
# Unique values in relationship:
# ['Own-child' 'Husband' 'Not-in-family' 'Unmarried' 'Wife' 'Other-relative']
#
# Unique values in race:
# ['Black' 'White' 'Other' 'Amer-Indian-Eskimo' 'Asian-Pac-Islander']
#
# ...

# %%
df[['age','hours-per-week','capital-gain','capital-loss']].describe()
# Out:
#                 age  hours-per-week  capital-gain  capital-loss
# count  45222.000000    45222.000000  44993.000000  45222.000000
# mean      38.547941       40.938017    598.073300     88.595418
# std       13.217870       12.007508   2568.660349    404.956092
# min       17.000000        1.000000      0.000000      0.000000
# 25%       28.000000       40.000000      0.000000      0.000000
# 50%       37.000000       40.000000      0.000000      0.000000
# 75%       47.000000       45.000000      0.000000      0.000000
# max       90.000000       99.000000  41310.000000   4356.000000

# %%
numeric_cols = ['age', 'hours-per-week', 'capital-gain', 'capital-loss']

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    print(f"{col}: {len(outliers)} outliers")
# Out:
# age: 269 outliers
# hours-per-week: 11899 outliers
# capital-gain: 3561 outliers
# capital-loss: 2140 outliers

# %%
df['age'].between(0, 100).all()
# Out:
# np.True_

# %%
df = df.drop(columns=['fnlwgt'])

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"\n{col}:")
    print(df[col].unique())
# Out:
# workclass:
# ['Private' 'Local-gov' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay']
#
# education:
# ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' '5th-6th' 'Assoc-voc' '9th' 'Doctorate'
#  '12th' '1st-4th' 'Preschool']
#
# marital-status:
# ['Never-married' 'Married-civ-spouse' 'Widowed' 'Separated' 'Divorced'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
# occupation:
# ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' 'Other-service'
#  'Prof-specialty' 'Craft-repair' 'Adm-clerical' 'Exec-managerial'
#  'Tech-support' 'Sales' 'Priv-house-serv' 'Transport-moving'
#  'Handlers-cleaners' 'Armed-Forces']
#
# relationship:
# ['Own-child' 'Husband' 'Not-in-family' 'Unmarried' 'Wife' 'Other-relative']
#
# race:
# ['Black' 'White' 'Other' 'Amer-Indian-Eskimo' 'Asian-Pac-Islander']
#
# gender:
# ['Male' 'Female']
#
# native-country:
# ...

# %%
df_encoded = pd.get_dummies(df, columns=['workclass', 'occupation'])

# %%
df['gender_binary'] = df['gender'].map({'Male': 0, 'Female': 1})

# %%
country_counts = df['native-country'].value_counts(normalize=True)

rare_countries = country_counts[country_counts < 0.01].index

df['native-country-grouped'] = df['native-country'].replace(rare_countries, 'Other')

# Show the new distribution
df['native-country-grouped'].value_counts().head(15)
# Out:
# native-country-grouped
# United States    41292
# Other             3027
# Mexico             903
# Name: count, dtype: int64

# %%
bins = [0, 25, 45, 65, 100]  # edges of the groups
labels = ['Young', 'Middle-aged', 'Senior', 'Elder']

df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
# 1 if capital-gain > 0 else 0
df['has_capital_gain'] = (df['capital-gain'] > 0).astype(int)

# 1 if capital-loss > 0 else 0
df['has_capital_loss'] = (df['capital-loss'] > 0).astype(int)

# %%
# Capital difference feature
df["capital-diff"] = df["capital-gain"] - df["capital-loss"]

# Is-married flag
df["is-married"] = df["marital-status"].apply(lambda x: 1 if "Married" in x else 0)

df[["capital-gain", "capital-loss", "capital-diff", "marital-status", "is-married"]].head(10)
# Out:
#     capital-gain  capital-loss  capital-diff      marital-status  is-married
# 0            0.0             0           0.0       Never-married           0
# 1            0.0             0           0.0  Married-civ-spouse           1
# 2            0.0             0           0.0  Married-civ-spouse           1
# 3         7688.0             0        7688.0  Married-civ-spouse           1
# 5            0.0             0           0.0       Never-married           0
# 7         3103.0             0        3103.0  Married-civ-spouse           1
# 8            0.0             0           0.0       Never-married           0
# 9            0.0             0           0.0  Married-civ-spouse           1
# 10        6418.0             0        6418.0  Married-civ-spouse           1
# 11           0.0             0           0.0  Married-civ-spouse           1

# %%
df.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 5   34    Private          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  ...  \
# 0  Machine-op-inspct      Own-child  Black   Male           0.0  ...
# 1    Farming-fishing        Husband  White   Male           0.0  ...
# 2    Protective-serv        Husband  White   Male           0.0  ...
# 3  Machine-op-inspct        Husband  Black   Male        7688.0  ...
# 5      Other-service  Not-in-family  White   Male           0.0  ...
#
#    hours-per-week  native-country income gender_binary  \
# 0              40   United States  <=50K             0
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
plt.hist(df['hours-per-week'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Hours per Week')
plt.show()

# %%
counts = df['education'].value_counts()
plt.bar(counts.index, counts.values, color='orange')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Bar Chart of Education Frquency')
plt.xticks(rotation=50)
plt.show()

# %%
counts = df['workclass'].value_counts()
plt.bar(counts.index, counts.values, color='orange')
plt.xlabel('Work Class')
plt.ylabel('Count')
plt.title('Bar Chart of Work Class Categories')
plt.xticks(rotation=50)
plt.show()

# %%
counts = df['occupation'].value_counts()
plt.bar(counts.index, counts.values, color='orange')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Bar Chart of Occupation Categories')
plt.xticks(rotation=50)
plt.show()

# %%
# Pie chart of 'gender'
counts = df['gender'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['skyblue','orange'])
plt.title('Pie Chart of Gender')
plt.show()

# %%
counts = df['race'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['skyblue','orange'])
plt.title('Pie Chart of race')
plt.show()

# %%
top10_countries = df['native-country'].value_counts().nlargest(10)

plt.bar(top10_countries.index, top10_countries.values, color='skyblue')
plt.xticks(rotation=45) 
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Top 10 Native Countries')
plt.show()

# %%
plt.hist(df['capital-gain'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Capital Gain')
plt.ylabel('Frequency')
plt.title('Histogram of Capitla Gain')
plt.show()

plt.hist(df['capital-loss'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Capital Loss')
plt.ylabel('Frequency')
plt.title('Histogram of Capital Loss')
plt.show()

# %%
import seaborn as sns
sns.countplot(x='income', data=df, palette='Set2')
plt.title('Countplot of Income')
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_5704\2181400430.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='income', data=df, palette='Set2')

# %%
income_vs_educatio_level = df.groupby("income")["educational-num"].sum()
plt.bar(income_vs_educatio_level.index, income_vs_educatio_level.values, color='orange')
plt.xlabel('income')
plt.ylabel('educational num')
plt.title('Bar Chart of Occupation Categories')
plt.xticks(rotation=50)
plt.show()

# %%
df.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 5   34    Private          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  ...  \
# 0  Machine-op-inspct      Own-child  Black   Male           0.0  ...
# 1    Farming-fishing        Husband  White   Male           0.0  ...
# 2    Protective-serv        Husband  White   Male           0.0  ...
# 3  Machine-op-inspct        Husband  Black   Male        7688.0  ...
# 5      Other-service  Not-in-family  White   Male           0.0  ...
#
#    hours-per-week  native-country income gender_binary  \
# 0              40   United States  <=50K             0
# ...
